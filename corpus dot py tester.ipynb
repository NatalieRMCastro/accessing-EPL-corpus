# %%
''' IMPORTING LIBRARIES '''

''' DATA ACCESS '''
import glob
import json
import sys

''' DATA QUERY '''
from lxml import etree
parser = etree.XMLParser(collect_ids=False,encoding='utf-8')
nsmap = {'tei': 'http://www.tei-c.org/ns/1.0'} ### EPL Source

''' DATA STRUCTURING '''
import pandas as pd

''' PROGRESS BAR '''
from tqdm.notebook import tqdm

''' FUNCTION DEFINITION '''

''' root generator function:

    INPUT: File Path from your machine
    OUTPUT: A parseable xml element that is TEI encoded

    The purpose of this function is to simplify the steps needed to get an xml file in parseable state. Any file name that
    is XML encoded will work for this function. 

'''


def root_generator(file_path):
    tree = etree.parse(file_path,parser)
    
    text_root = tree.getroot()
    
    return(text_root)

''' root generator function:

    INPUT: A text root
    OUTPUT: The TEI tag to identify this book

    The purpose of this function is to extract the unique TEI tag from the file. It will return a string with the TEI inside 

'''

def tei_finder(text_root):
    tei_tag = text_root.findall(".//tei:idno[@ type='DLPS']",namespaces=nsmap)
    tei = [tag.text for tag in tei_tag]
    return (tei[0])

''' extract_all_words function:

    This function is intended to extract all of the words from the text file. 
    This will include the title, author, publisher, and all other metadata that may be included in the text. 
    
    INPUT: an xml tree tag
    OUTPUT: a list containing all of the words

'''
def extract_all_words(text_root):
    all_word_tags = text_root.findall(".//tei:w",namespaces=nsmap)
    
    all_words = [w.text for w in all_word_tags]
    
    return(all_words)


''' extract_all_modernized_words function:

    This function will generate a list of the modernized words generated by the NUIT Morphadorner. This function performs similarly
    to the orignal text function above, but just pulls a different XML tag.
    
    INPUT: an xml tree tag
    OUTPUT: a list containing all of the modernized words


'''

def extract_all_modernized_words(text_root):
    all_word_tags = text_root.findall(".//tei:w",namespaces=nsmap)
    
    regularized_words = [w.get('reg', w.text) for w in all_word_tags]
    
    
    return(regularized_words)

''' extract_all_lemmas function:

    This function will generate a list of the lemmatized words by EPL. It works in a similar fashion to those above.
    
    INPUT: an xml tree tag
    OUTPUT: a list containing all of the lemmatized words



'''

def extract_all_lemmas(text_root):
    all_word_tags = text_root.findall(".//tei:w",namespaces=nsmap)
    
    lemmas = [w.get('lemma') for w in all_word_tags]
    
    
    return(lemmas)


''' extract_all_pos function:

    This function will generate a list of the Parts of Speech Tags attributed to each individual word. These were generated
    
    INPUT: an xml tree tag
    OUTPUT: a list containing all of the POS tags for each respective word

'''

def extract_all_pos(text_root):
    all_word_tags = text_root.findall(".//tei:w",namespaces=nsmap)
    
    pos = [w.get('pos') for w in all_word_tags]
    
    return(pos)

''' extract_all_sentences function:

    INPUT: an xml text root
    OUTPUT: a list of strings that are each a sentence in the text
    
    This function is heavily adopted from the EPL documentation linked above. Naming conventions were changed from 'master'
    to 'main', and the code comments were changed as well to increased readability in this file. This function, like the word
    functions, will take an xml text root and geneare a split list based on the text provided. This function can take some
    time to run, as it iterates through the tags one by one.

'''

def extract_all_sentences(text_root):
    word_and_punctuation_tags = text_root.xpath("//tei:w|//tei:pc", namespaces=nsmap)
    
    
        ## Creating list storage containers for the working text
    all_sentences = []
    new_sentence = []
    
        ## Iterating through each tag
    
    for tag in word_and_punctuation_tags:
        ## First, we will test to see if the tag has the attribute to find the end of the sentence
        if 'unit' in tag.attrib and tag.get('unit') == 'sentence':
            if tag.text != None:
                ## Adding the punctuation to the sentence
                new_sentence.append(tag.text)
            
            joined_sentence = ' '.join([word for word in new_sentence if word is not None])
            ## Storing the sentences
            all_sentences.append(joined_sentence)
            ## Reinstantiating the working sentence storage container
            new_sentence = []
        # If the tag is not at the end of a sentence, we can simply add its contents to the list
        else:
            new_sentence.append(tag.text)
            
    
    return (all_sentences)


''' function: iterative dataframe maker'''
def by_word_dataframe_maker(files):
    text_data = [] # Empty list for data
    
    ## extracting the metadata from each file
    for file_name in files:
            ## Finding TEI and creating a parse object
        root = root_generator(file_name)
        tei = tei_finder(root)

            ## Parsing the object using the above functions

        words = extract_all_words(root)
        modernized = extract_all_modernized_words(root)
        lemmas = extract_all_lemmas(root)
        pos = extract_all_pos(root)

        current_text = {'TEI':tei,'words':words,'modernized':modernized,'lemmas':lemmas,'pos':pos}
        text_data.append(current_text)
          

    tei_data = pd.DataFrame(text_data)
    #word_data = tei_data.apply(pd.Series.explode)
    
   
    
    repo_tei_code_first = tei_data.at[0,'TEI']
    repo_tei_code = repo_tei_code_first[0:3]

    text_file_name = str(repo_tei_code)+" FULL Text Data.csv"
    by_word_file_name = str(repo_tei_code)+ " SPLIT Word Data.csv"
    
    tei_data.to_csv(text_file_name)
    #word_data.to_csv(by_word_file_name)
    
    
    
''' function: sentence dataframe maker'''

def by_sentence_dataframe_maker(files):
    sentence_data = [] # Empty list for data
    teis = [] # Empty list for TCP IDs

    ## extracting the metadata from each file
    for file_name in files:
            ## Finding TEI and creating a parse object
        root = root_generator(file_name)
        tei = tei_finder(root)
        teis.append(tei)

            ## Parsing the object using the above functions
        sentences = extract_all_sentences(root)

        current_text = {'TEI':tei,'sentences':sentences}
        sentence_data.append(current_text)


    tei_full_sentences = pd.DataFrame(sentence_data)
    #tei_sentences = tei_full_sentences.explode(column='sentences')

    
    repo_tei_code_first = tei_full_sentences.at[0,'TEI']
    repo_tei_code = repo_tei_code_first[0:3]
    
    sentence_full_file_name = str(repo_tei_code)+" FULL Sentence Data.csv"
    sentence_file_name = str(repo_tei_code)+" SPLIT Sentence Data.csv"
    tei_full_sentences.to_csv(sentence_full_file_name)
    #tei_sentences.to_csv(sentence_file_name)
    

''' function: folder iteration and data generation '''
## naming the line aregument from the slurm script
folder_name = sys.argv[1]

with open("output.txt", 'w') as f:
    f.write(f"{folder_name} | using folder iterator")
    f.write(f" folder: {folder_name}")

# %%
''' function: iterative dataframe maker'''
def by_word_dataframe_maker(files):
    text_data = [] # Empty list for data
    
    print ("... iterating through files")
    ## extracting the metadata from each file
    for file_name in files:
            ## Finding TEI and creating a parse object
        
        root = root_generator(file_name)
        print ("text found")
        tei = tei_finder(root)
        print (f"TEI found {tei}")
        
            ## Parsing the object using the above functions
        print ("finding words, lemmas, and POS")
        words = extract_all_words(root)
        modernized = extract_all_modernized_words(root)
        lemmas = extract_all_lemmas(root)
        pos = extract_all_pos(root)

        current_text = {'TEI':tei,'words':words,'modernized':modernized,'lemmas':lemmas,'pos':pos}
        text_data.append(current_text)
          

    tei_data = pd.DataFrame(text_data)
    #word_data = tei_data.apply(pd.Series.explode)
    print ("data frame has successfully been created")
   
    
    repo_tei_code_first = tei_data.at[0,'TEI']
    repo_tei_code = repo_tei_code_first[0:3]

    text_file_name = str(repo_tei_code)+" FULL Text Data.csv"
    by_word_file_name = str(repo_tei_code)+ " SPLIT Word Data.csv"
    
    tei_data.to_csv(text_file_name)
    #word_data.to_csv(by_word_file_name)
    print ("csv has successfully been generated")

# %%
xml_files = glob.glob(f"/scratch/alpine/naca4005/texts/A09/*.xml")

by_word_dataframe_maker(xml_files)
# Out:
# ... iterating through files
# text found
# TEI found A09291
# finding words, lemmas, and POS
# text found
# TEI found A09205
# finding words, lemmas, and POS
# text found
# TEI found A09526
# finding words, lemmas, and POS
# text found
# TEI found A09495
# finding words, lemmas, and POS
# text found
# TEI found A09108
# finding words, lemmas, and POS
# text found
# TEI found A09052
# finding words, lemmas, and POS
# text found
# TEI found A09876
# finding words, lemmas, and POS
# text found
# TEI found A09107
# finding words, lemmas, and POS
# text found
# TEI found A09579
# finding words, lemmas, and POS
# text found
# TEI found A09417
# finding words, lemmas, and POS
# text found
# TEI found A09138
# finding words, lemmas, and POS
# text found
# TEI found A09142
# finding words, lemmas, and POS
# text found
# TEI found A09235
# finding words, lemmas, and POS
# text found
# TEI found A09418
# finding words, lemmas, and POS
# text found
# TEI found A09086
# finding words, lemmas, and POS
# text found
# TEI found A09739
# finding words, lemmas, and POS
# text found
# TEI found A09911
# finding words, lemmas, and POS
# text found
# TEI found A09377
# finding words, lemmas, and POS
# text found
# TEI found A09581
# finding words, lemmas, and POS
# text found
# TEI found A09527
# finding words, lemmas, and POS
# text found
# TEI found A09895
# finding words, lemmas, and POS
# text found
# TEI found A09639
# finding words, lemmas, and POS
# text found
# TEI found A09237
# finding words, lemmas, and POS
# text found
# TEI found A09362
# finding words, lemmas, and POS
# text found
# TEI found A09758
# finding words, lemmas, and POS
# text found
# TEI found A09904
# finding words, lemmas, and POS
# text found
# TEI found A09831
# finding words, lemmas, and POS
# text found
# TEI found A09203
# finding words, lemmas, and POS
# text found
# TEI found A09272
# finding words, lemmas, and POS
# text found
# TEI found A09221
# finding words, lemmas, and POS
# text found
# TEI found A09799
# finding words, lemmas, and POS
# text found
# TEI found A09211
# finding words, lemmas, and POS
# text found
# TEI found A09868
# finding words, lemmas, and POS
# text found
# TEI found A09253
# finding words, lemmas, and POS
# text found
# TEI found A09163
# finding words, lemmas, and POS
# text found
# TEI found A09001
# finding words, lemmas, and POS
# text found
# TEI found A09949
# finding words, lemmas, and POS
# text found
# TEI found A09977
# finding words, lemmas, and POS
# text found
# TEI found A09255
# finding words, lemmas, and POS
# text found
# TEI found A09829
# finding words, lemmas, and POS
# text found
# TEI found A09958
# finding words, lemmas, and POS
# text found
# TEI found A09741
# finding words, lemmas, and POS
# text found
# TEI found A09618
# finding words, lemmas, and POS
# text found
# TEI found A09921
# finding words, lemmas, and POS
# text found
# TEI found A09100
# finding words, lemmas, and POS
# text found
# TEI found A09442
# finding words, lemmas, and POS
# text found
# TEI found A09658
# finding words, lemmas, and POS
# text found
# TEI found A09957
# finding words, lemmas, and POS
# text found
# TEI found A09899
# finding words, lemmas, and POS
# text found
# TEI found A09947
# finding words, lemmas, and POS
# text found
# TEI found A09832
# finding words, lemmas, and POS
# text found
# TEI found A09043
# finding words, lemmas, and POS
# text found
# TEI found A09149
# finding words, lemmas, and POS
# text found
# TEI found A09201
# finding words, lemmas, and POS
# text found
# TEI found A09578
# finding words, lemmas, and POS
# text found
# TEI found A09208
# finding words, lemmas, and POS
# text found
# TEI found A09610
# finding words, lemmas, and POS
# text found
# TEI found A09133
# finding words, lemmas, and POS
# text found
# TEI found A09880
# finding words, lemmas, and POS
# text found
# TEI found A09031
# finding words, lemmas, and POS
# text found
# TEI found A09189
# finding words, lemmas, and POS
# text found
# TEI found A09634
# finding words, lemmas, and POS
# text found
# TEI found A09010
# finding words, lemmas, and POS
# text found
# TEI found A09569
# finding words, lemmas, and POS
# text found
# TEI found A09865
# finding words, lemmas, and POS
# text found
# TEI found A09319
# finding words, lemmas, and POS
# text found
# TEI found A09830
# finding words, lemmas, and POS
# text found
# TEI found A09181
# finding words, lemmas, and POS
# text found
# TEI found A09147
# finding words, lemmas, and POS
# text found
# TEI found A09959
# finding words, lemmas, and POS
# text found
# TEI found A09974
# finding words, lemmas, and POS
# text found
# TEI found A09097
# finding words, lemmas, and POS
# text found
# TEI found A09906
# finding words, lemmas, and POS
# text found
# TEI found A09207
# finding words, lemmas, and POS
# text found
# TEI found A09407
# finding words, lemmas, and POS
# text found
# TEI found A09303
# finding words, lemmas, and POS
# text found
# TEI found A09101
# finding words, lemmas, and POS
# text found
# TEI found A09867
# finding words, lemmas, and POS
# text found
# TEI found A09609
# finding words, lemmas, and POS
# text found
# TEI found A09113
# finding words, lemmas, and POS
# text found
# TEI found A09353
# finding words, lemmas, and POS
# text found
# TEI found A09750
# finding words, lemmas, and POS
# text found
# TEI found A09841
# finding words, lemmas, and POS
# text found
# TEI found A09633
# finding words, lemmas, and POS
# text found
# TEI found A09596
# finding words, lemmas, and POS
# text found
# TEI found A09061
# finding words, lemmas, and POS
# text found
# TEI found A09677
# finding words, lemmas, and POS
# text found
# TEI found A09908
# finding words, lemmas, and POS
# text found
# TEI found A09411
# finding words, lemmas, and POS
# text found
# TEI found A09466
# finding words, lemmas, and POS
# text found
# TEI found A09532
# finding words, lemmas, and POS
# text found
# TEI found A09295
# finding words, lemmas, and POS
# text found
# TEI found A09531
# finding words, lemmas, and POS
# text found
# TEI found A09426
# finding words, lemmas, and POS
# text found
# TEI found A09333
# finding words, lemmas, and POS
# text found
# TEI found A09298
# finding words, lemmas, and POS
# text found
# TEI found A09819
# finding words, lemmas, and POS
# text found
# TEI found A09883
# finding words, lemmas, and POS
# text found
# TEI found A09891
# finding words, lemmas, and POS
# text found
# TEI found A09103
# finding words, lemmas, and POS
# text found
# TEI found A09800
# finding words, lemmas, and POS
# text found
# TEI found A09216
# finding words, lemmas, and POS
# text found
# TEI found A09000
# finding words, lemmas, and POS
# text found
# TEI found A09429
# finding words, lemmas, and POS
# text found
# TEI found A09791
# finding words, lemmas, and POS
# text found
# TEI found A09533
# finding words, lemmas, and POS
# text found
# TEI found A09284
# finding words, lemmas, and POS
# text found
# TEI found A09711
# finding words, lemmas, and POS
# text found
# TEI found A09238
# finding words, lemmas, and POS
# text found
# TEI found A09441
# finding words, lemmas, and POS
# text found
# TEI found A09724
# finding words, lemmas, and POS
# text found
# TEI found A09239
# finding words, lemmas, and POS
# text found
# TEI found A09331
# finding words, lemmas, and POS
# text found
# TEI found A09605
# finding words, lemmas, and POS
# text found
# TEI found A09479
# finding words, lemmas, and POS
# text found
# TEI found A09606
# finding words, lemmas, and POS
# text found
# TEI found A09194
# finding words, lemmas, and POS
# text found
# TEI found A09386
# finding words, lemmas, and POS
# text found
# TEI found A09745
# finding words, lemmas, and POS
# text found
# TEI found A09393
# finding words, lemmas, and POS
# text found
# TEI found A09262
# finding words, lemmas, and POS
# text found
# TEI found A09118
# finding words, lemmas, and POS
# text found
# TEI found A09646
# finding words, lemmas, and POS
# text found
# TEI found A09528
# finding words, lemmas, and POS
# text found
# TEI found A09604
# finding words, lemmas, and POS
# text found
# TEI found A09026
# finding words, lemmas, and POS
# text found
# TEI found A09763
# finding words, lemmas, and POS
# text found
# TEI found A09450
# finding words, lemmas, and POS
# text found
# TEI found A09704
# finding words, lemmas, and POS
# text found
# TEI found A09115
# finding words, lemmas, and POS
# text found
# TEI found A09486
# finding words, lemmas, and POS
# text found
# TEI found A09641
# finding words, lemmas, and POS
# text found
# TEI found A09490
# finding words, lemmas, and POS
# text found
# TEI found A09599
# finding words, lemmas, and POS
# text found
# TEI found A09583
# finding words, lemmas, and POS
# text found
# TEI found A09765
# finding words, lemmas, and POS
# text found
# TEI found A09897
# finding words, lemmas, and POS
# text found
# TEI found A09930
# finding words, lemmas, and POS
# text found
# TEI found A09990
# finding words, lemmas, and POS
# text found
# TEI found A09628
# finding words, lemmas, and POS
# text found
# TEI found A09173
# finding words, lemmas, and POS
# text found
# TEI found A09976
# finding words, lemmas, and POS
# text found
# TEI found A09224
# finding words, lemmas, and POS
# text found
# TEI found A09838
# finding words, lemmas, and POS
# text found
# TEI found A09367
# finding words, lemmas, and POS
# text found
# TEI found A09266
# finding words, lemmas, and POS
# text found
# TEI found A09213
# finding words, lemmas, and POS
# text found
# TEI found A09862
# finding words, lemmas, and POS
# text found
# TEI found A09857
# finding words, lemmas, and POS
# text found
# TEI found A09956
# finding words, lemmas, and POS
# text found
# TEI found A09493
# finding words, lemmas, and POS
# text found
# TEI found A09759
# finding words, lemmas, and POS
# text found
# TEI found A09731
# finding words, lemmas, and POS
# text found
# TEI found A09760
# finding words, lemmas, and POS
# text found
# TEI found A09674
# finding words, lemmas, and POS
# text found
# TEI found A09626
# finding words, lemmas, and POS
# text found
# TEI found A09461
# finding words, lemmas, and POS
# text found
# TEI found A09900
# finding words, lemmas, and POS
# text found
# TEI found A09055
# finding words, lemmas, and POS
# text found
# TEI found A09736
# finding words, lemmas, and POS
# text found
# TEI found A09766
# finding words, lemmas, and POS
# text found
# TEI found A09846
# finding words, lemmas, and POS
# text found
# TEI found A09530
# finding words, lemmas, and POS
# text found
# TEI found A09220
# finding words, lemmas, and POS
# text found
# TEI found A09521
# finding words, lemmas, and POS
# text found
# TEI found A09171
# finding words, lemmas, and POS
# text found
# TEI found A09971
# finding words, lemmas, and POS
# text found
# TEI found A09094
# finding words, lemmas, and POS
# text found
# TEI found A09584
# finding words, lemmas, and POS
# text found
# TEI found A09973
# finding words, lemmas, and POS
# text found
# TEI found A09035
# finding words, lemmas, and POS
# text found
# TEI found A09798
# finding words, lemmas, and POS
# text found
# TEI found A09264
# finding words, lemmas, and POS
# text found
# TEI found A09559
# finding words, lemmas, and POS
# text found
# TEI found A09044
# finding words, lemmas, and POS
# text found
# TEI found A09114
# finding words, lemmas, and POS
# text found
# TEI found A09512
# finding words, lemmas, and POS
# text found
# TEI found A09923
# finding words, lemmas, and POS
# text found
# TEI found A09307
# finding words, lemmas, and POS
# text found
# TEI found A09809
# finding words, lemmas, and POS
# text found
# TEI found A09129
# finding words, lemmas, and POS
# text found
# TEI found A09209
# finding words, lemmas, and POS
# text found
# TEI found A09382
# finding words, lemmas, and POS
# text found
# TEI found A09505
# finding words, lemmas, and POS
# text found
# TEI found A09907
# finding words, lemmas, and POS
# text found
# TEI found A09510
# finding words, lemmas, and POS
# text found
# TEI found A09859
# finding words, lemmas, and POS
# text found
# TEI found A09077
# finding words, lemmas, and POS
# text found
# TEI found A09847
# finding words, lemmas, and POS
# text found
# TEI found A09918
# finding words, lemmas, and POS
# text found
# TEI found A09268
# finding words, lemmas, and POS
# text found
# TEI found A09228
# finding words, lemmas, and POS
# text found
# TEI found A09849
# finding words, lemmas, and POS
# text found
# TEI found A09402
# finding words, lemmas, and POS
# text found
# TEI found A09935
# finding words, lemmas, and POS
# text found
# TEI found A09706
# finding words, lemmas, and POS
# text found
# TEI found A09436
# finding words, lemmas, and POS
# text found
# TEI found A09039
# finding words, lemmas, and POS
# text found
# TEI found A09588
# finding words, lemmas, and POS
# text found
# TEI found A09507
# finding words, lemmas, and POS
# text found
# TEI found A09403
# finding words, lemmas, and POS
# text found
# TEI found A09598
# finding words, lemmas, and POS
# text found
# TEI found A09443
# finding words, lemmas, and POS
# text found
# TEI found A09294
# finding words, lemmas, and POS
# text found
# TEI found A09576
# finding words, lemmas, and POS
# text found
# TEI found A09123
# finding words, lemmas, and POS
# text found
# TEI found A09499
# finding words, lemmas, and POS
# text found
# TEI found A09654
# finding words, lemmas, and POS
# text found
# TEI found A09525
# finding words, lemmas, and POS
# text found
# TEI found A09950
# finding words, lemmas, and POS
# text found
# TEI found A09539
# finding words, lemmas, and POS
# text found
# TEI found A09192
# finding words, lemmas, and POS
# text found
# TEI found A09144
# finding words, lemmas, and POS
# text found
# TEI found A09383
# finding words, lemmas, and POS
# text found
# TEI found A09885
# finding words, lemmas, and POS
# text found
# TEI found A09827
# finding words, lemmas, and POS
# text found
# TEI found A09620
# finding words, lemmas, and POS
# text found
# TEI found A09589
# finding words, lemmas, and POS
# text found
# TEI found A09822
# finding words, lemmas, and POS
# text found
# TEI found A09287
# finding words, lemmas, and POS
# text found
# TEI found A09887
# finding words, lemmas, and POS
# text found
# TEI found A09881
# finding words, lemmas, and POS
# text found
# TEI found A09913
# finding words, lemmas, and POS
# text found
# TEI found A09545
# finding words, lemmas, and POS
# text found
# TEI found A09811
# finding words, lemmas, and POS
# text found
# TEI found A09188
# finding words, lemmas, and POS
# text found
# TEI found A09242
# finding words, lemmas, and POS
# text found
# TEI found A09165
# finding words, lemmas, and POS
# text found
# TEI found A09744
# finding words, lemmas, and POS
# text found
# TEI found A09967
# finding words, lemmas, and POS
# text found
# TEI found A09551
# finding words, lemmas, and POS
# text found
# TEI found A09497
# finding words, lemmas, and POS
# text found
# TEI found A09651
# finding words, lemmas, and POS
# text found
# TEI found A09813
# finding words, lemmas, and POS
# text found
# TEI found A09053
# finding words, lemmas, and POS
# text found
# TEI found A09265
# finding words, lemmas, and POS
# text found
# TEI found A09514
# finding words, lemmas, and POS
# text found
# TEI found A09781
# finding words, lemmas, and POS
# text found
# TEI found A09524
# finding words, lemmas, and POS
# text found
# TEI found A09952
# finding words, lemmas, and POS
# text found
# TEI found A09984
# finding words, lemmas, and POS
# text found
# TEI found A09219
# finding words, lemmas, and POS
# text found
# TEI found A09204
# finding words, lemmas, and POS
# text found
# TEI found A09934
# finding words, lemmas, and POS
# text found
# TEI found A09500
# finding words, lemmas, and POS
# text found
# TEI found A09653
# finding words, lemmas, and POS
# text found
# TEI found A09017
# finding words, lemmas, and POS
# text found
# TEI found A09315
# finding words, lemmas, and POS
# text found
# TEI found A09553
# finding words, lemmas, and POS
# text found
# TEI found A09232
# finding words, lemmas, and POS
# text found
# TEI found A09463
# finding words, lemmas, and POS
# text found
# TEI found A09659
# finding words, lemmas, and POS
# text found
# TEI found A09506
# finding words, lemmas, and POS
# text found
# TEI found A09942
# finding words, lemmas, and POS
# text found
# TEI found A09312
# finding words, lemmas, and POS
# text found
# TEI found A09051
# finding words, lemmas, and POS
# text found
# TEI found A09274
# finding words, lemmas, and POS
# text found
# TEI found A09339
# finding words, lemmas, and POS
# text found
# TEI found A09697
# finding words, lemmas, and POS
# text found
# TEI found A09586
# finding words, lemmas, and POS
# text found
# TEI found A09002
# finding words, lemmas, and POS
# text found
# TEI found A09218
# finding words, lemmas, and POS
# text found
# TEI found A09790
# finding words, lemmas, and POS
# text found
# TEI found A09509
# finding words, lemmas, and POS
# text found
# TEI found A09518
# finding words, lemmas, and POS
# text found
# TEI found A09999
# finding words, lemmas, and POS
# text found
# TEI found A09666
# finding words, lemmas, and POS
# text found
# TEI found A09439
# finding words, lemmas, and POS
# text found
# TEI found A09667
# finding words, lemmas, and POS
# text found
# TEI found A09406
# finding words, lemmas, and POS
# text found
# TEI found A09522
# finding words, lemmas, and POS
# text found
# TEI found A09580
# finding words, lemmas, and POS
# text found
# TEI found A09645
# finding words, lemmas, and POS
# text found
# TEI found A09632
# finding words, lemmas, and POS
# text found
# TEI found A09848
# finding words, lemmas, and POS
# text found
# TEI found A09135
# finding words, lemmas, and POS
# text found
# TEI found A09156
# finding words, lemmas, and POS
# text found
# TEI found A09046
# finding words, lemmas, and POS
# text found
# TEI found A09178
# finding words, lemmas, and POS
# text found
# TEI found A09729
# finding words, lemmas, and POS
# text found
# TEI found A09387
# finding words, lemmas, and POS
# text found
# TEI found A09823
# finding words, lemmas, and POS
# text found
# TEI found A09134
# finding words, lemmas, and POS
# text found
# TEI found A09488
# finding words, lemmas, and POS
# text found
# TEI found A09582
# finding words, lemmas, and POS
# text found
# TEI found A09491
# finding words, lemmas, and POS
# text found
# TEI found A09561
# finding words, lemmas, and POS
# text found
# TEI found A09112
# finding words, lemmas, and POS
# text found
# TEI found A09970
# finding words, lemmas, and POS
# text found
# TEI found A09175
# finding words, lemmas, and POS
# text found
# TEI found A09910
# finding words, lemmas, and POS
# text found
# TEI found A09661
# finding words, lemmas, and POS
# text found
# TEI found A09513
# finding words, lemmas, and POS
# text found
# TEI found A09644
# finding words, lemmas, and POS
# text found
# TEI found A09607
# finding words, lemmas, and POS
# text found
# TEI found A09851
# finding words, lemmas, and POS
# text found
# TEI found A09965
# finding words, lemmas, and POS
# text found
# TEI found A09997
# finding words, lemmas, and POS
# text found
# TEI found A09226
# finding words, lemmas, and POS
# text found
# TEI found A09740
# finding words, lemmas, and POS
# text found
# TEI found A09905
# finding words, lemmas, and POS
# text found
# TEI found A09782
# finding words, lemmas, and POS
# text found
# TEI found A09445
# finding words, lemmas, and POS
# text found
# TEI found A09364
# finding words, lemmas, and POS
# text found
# TEI found A09631
# finding words, lemmas, and POS
# text found
# TEI found A09828
# finding words, lemmas, and POS
# text found
# TEI found A09365
# finding words, lemmas, and POS
# text found
# TEI found A09300
# finding words, lemmas, and POS
# text found
# TEI found A09931
# finding words, lemmas, and POS
# text found
# TEI found A09376
# finding words, lemmas, and POS
# text found
# TEI found A09668
# finding words, lemmas, and POS
# text found
# TEI found A09909
# finding words, lemmas, and POS
# text found
# TEI found A09789
# finding words, lemmas, and POS
# text found
# TEI found A09593
# finding words, lemmas, and POS
# text found
# TEI found A09732
# finding words, lemmas, and POS
# text found
# TEI found A09254
# finding words, lemmas, and POS
# text found
# TEI found A09502
# finding words, lemmas, and POS
# text found
# TEI found A09088
# finding words, lemmas, and POS
# text found
# TEI found A09137
# finding words, lemmas, and POS
# text found
# TEI found A09404
# finding words, lemmas, and POS
# text found
# TEI found A09233
# finding words, lemmas, and POS
# text found
# TEI found A09008
# finding words, lemmas, and POS
# text found
# TEI found A09012
# finding words, lemmas, and POS
# text found
# TEI found A09212
# finding words, lemmas, and POS
# text found
# TEI found A09313
# finding words, lemmas, and POS
# text found
# TEI found A09780
# finding words, lemmas, and POS
# text found
# TEI found A09915
# finding words, lemmas, and POS
# text found
# TEI found A09538
# finding words, lemmas, and POS
# text found
# TEI found A09810
# finding words, lemmas, and POS
# text found
# TEI found A09279
# finding words, lemmas, and POS
# text found
# TEI found A09574
# finding words, lemmas, and POS
# text found
# TEI found A09062
# finding words, lemmas, and POS
# text found
# TEI found A09926
# finding words, lemmas, and POS
# text found
# TEI found A09258
# finding words, lemmas, and POS
# text found
# TEI found A09944
# finding words, lemmas, and POS
# text found
# TEI found A09678
# finding words, lemmas, and POS
# text found
# TEI found A09585
# finding words, lemmas, and POS
# text found
# TEI found A09635
# finding words, lemmas, and POS
# text found
# TEI found A09297
# finding words, lemmas, and POS
# text found
# TEI found A09772
# finding words, lemmas, and POS
# text found
# TEI found A09038
# finding words, lemmas, and POS
# text found
# TEI found A09388
# finding words, lemmas, and POS
# text found
# TEI found A09015
# finding words, lemmas, and POS
# text found
# TEI found A09316
# finding words, lemmas, and POS
# text found
# TEI found A09275
# finding words, lemmas, and POS
# text found
# TEI found A09850
# finding words, lemmas, and POS
# text found
# TEI found A09529
# finding words, lemmas, and POS
# text found
# TEI found A09844
# finding words, lemmas, and POS
# text found
# TEI found A09824
# finding words, lemmas, and POS
# text found
# TEI found A09932
# finding words, lemmas, and POS
# text found
# TEI found A09400
# finding words, lemmas, and POS
# text found
# TEI found A09972
# finding words, lemmas, and POS
# text found
# TEI found A09197
# finding words, lemmas, and POS
# text found
# TEI found A09517
# finding words, lemmas, and POS
# text found
# TEI found A09117
# finding words, lemmas, and POS
# text found
# TEI found A09946
# finding words, lemmas, and POS
# text found
# TEI found A09842
# finding words, lemmas, and POS
# text found
# TEI found A09981
# finding words, lemmas, and POS
# text found
# TEI found A09320
# finding words, lemmas, and POS
# text found
# TEI found A09591
# finding words, lemmas, and POS
# text found
# TEI found A09963
# finding words, lemmas, and POS
# text found
# TEI found A09405
# finding words, lemmas, and POS
# text found
# TEI found A09098
# finding words, lemmas, and POS
# text found
# TEI found A09636
# finding words, lemmas, and POS
# text found
# TEI found A09104
# finding words, lemmas, and POS
# text found
# TEI found A09380
# finding words, lemmas, and POS
# text found
# TEI found A09013
# finding words, lemmas, and POS
# text found
# TEI found A09170
# finding words, lemmas, and POS
# text found
# TEI found A09289
# finding words, lemmas, and POS
# text found
# TEI found A09063
# finding words, lemmas, and POS
# text found
# TEI found A09554
# finding words, lemmas, and POS
# text found
# TEI found A09472
# finding words, lemmas, and POS
# text found
# TEI found A09230
# finding words, lemmas, and POS
# text found
# TEI found A09092
# finding words, lemmas, and POS
# text found
# TEI found A09702
# finding words, lemmas, and POS
# text found
# TEI found A09024
# finding words, lemmas, and POS
# text found
# TEI found A09733
# finding words, lemmas, and POS
# text found
# TEI found A09590
# finding words, lemmas, and POS
# text found
# TEI found A09713
# finding words, lemmas, and POS
# text found
# TEI found A09922
# finding words, lemmas, and POS
# text found
# TEI found A09592
# finding words, lemmas, and POS
# text found
# TEI found A09106
# finding words, lemmas, and POS
# text found
# TEI found A09695
# finding words, lemmas, and POS
# text found
# TEI found A09738
# finding words, lemmas, and POS
# text found
# TEI found A09049
# finding words, lemmas, and POS
# text found
# TEI found A09595
# finding words, lemmas, and POS
# text found
# TEI found A09462
# finding words, lemmas, and POS
# text found
# TEI found A09288
# finding words, lemmas, and POS
# text found
# TEI found A09410
# finding words, lemmas, and POS
# text found
# TEI found A09222
# finding words, lemmas, and POS
# text found
# TEI found A09056
# finding words, lemmas, and POS
# text found
# TEI found A09757
# finding words, lemmas, and POS
# text found
# TEI found A09616
# finding words, lemmas, and POS
# text found
# TEI found A09826
# finding words, lemmas, and POS
# text found
# TEI found A09833
# finding words, lemmas, and POS
# text found
# TEI found A09473
# finding words, lemmas, and POS
# text found
# TEI found A09179
# finding words, lemmas, and POS
# text found
# TEI found A09675
# finding words, lemmas, and POS
# text found
# TEI found A09198
# finding words, lemmas, and POS
# text found
# TEI found A09875
# finding words, lemmas, and POS
# text found
# TEI found A09627
# finding words, lemmas, and POS
# text found
# TEI found A09793
# finding words, lemmas, and POS
# text found
# TEI found A09182
# finding words, lemmas, and POS
# text found
# TEI found A09914
# finding words, lemmas, and POS
# text found
# TEI found A09176
# finding words, lemmas, and POS
# text found
# TEI found A09928
# finding words, lemmas, and POS
# text found
# TEI found A09453
# finding words, lemmas, and POS
# text found
# TEI found A09202
# finding words, lemmas, and POS
# text found
# TEI found A09432
# finding words, lemmas, and POS
# text found
# TEI found A09564
# finding words, lemmas, and POS
# text found
# TEI found A09487
# finding words, lemmas, and POS
# text found
# TEI found A09869
# finding words, lemmas, and POS
# text found
# TEI found A09465
# finding words, lemmas, and POS
# text found
# TEI found A09537
# finding words, lemmas, and POS
# text found
# TEI found A09054
# finding words, lemmas, and POS
# text found
# TEI found A09040
# finding words, lemmas, and POS
# text found
# TEI found A09707
# finding words, lemmas, and POS
# text found
# TEI found A09703
# finding words, lemmas, and POS
# text found
# TEI found A09852
# finding words, lemmas, and POS
# text found
# TEI found A09575
# finding words, lemmas, and POS
# text found
# TEI found A09916
# finding words, lemmas, and POS
# text found
# TEI found A09998
# finding words, lemmas, and POS
# text found
# TEI found A09938
# finding words, lemmas, and POS
# text found
# TEI found A09734
# finding words, lemmas, and POS
# text found
# TEI found A09945
# finding words, lemmas, and POS
# text found
# TEI found A09927
# finding words, lemmas, and POS
# text found
# TEI found A09568
# finding words, lemmas, and POS
# text found
# TEI found A09105
# finding words, lemmas, and POS
# text found
# TEI found A09563
# finding words, lemmas, and POS
# text found
# TEI found A09670
# finding words, lemmas, and POS
# text found
# TEI found A09649
# finding words, lemmas, and POS
# text found
# TEI found A09562
# finding words, lemmas, and POS
# text found
# TEI found A09434
# finding words, lemmas, and POS
# text found
# TEI found A09057
# finding words, lemmas, and POS
# text found
# TEI found A09286
# finding words, lemmas, and POS
# text found
# TEI found A09111
# finding words, lemmas, and POS
# text found
# TEI found A09449
# finding words, lemmas, and POS
# text found
# TEI found A09523
# finding words, lemmas, and POS
# text found
# TEI found A09227
# finding words, lemmas, and POS
# text found
# TEI found A09662
# finding words, lemmas, and POS
# text found
# TEI found A09206
# finding words, lemmas, and POS
# text found
# TEI found A09710
# finding words, lemmas, and POS
# text found
# TEI found A09223
# finding words, lemmas, and POS
# text found
# TEI found A09183
# finding words, lemmas, and POS
# text found
# TEI found A09665
# finding words, lemmas, and POS
# text found
# TEI found A09292
# finding words, lemmas, and POS
# text found
# TEI found A09391
# finding words, lemmas, and POS
# text found
# TEI found A09252
# finding words, lemmas, and POS
# text found
# TEI found A09676
# finding words, lemmas, and POS
# text found
# TEI found A09195
# finding words, lemmas, and POS
# text found
# TEI found A09864
# finding words, lemmas, and POS
# text found
# TEI found A09151
# finding words, lemmas, and POS
# text found
# TEI found A09597
# finding words, lemmas, and POS
# text found
# TEI found A09011
# finding words, lemmas, and POS
# text found
# TEI found A09753
# finding words, lemmas, and POS
# text found
# TEI found A09014
# finding words, lemmas, and POS
# text found
# TEI found A09802
# finding words, lemmas, and POS
# text found
# TEI found A09304
# finding words, lemmas, and POS
# text found
# TEI found A09102
# finding words, lemmas, and POS
# text found
# TEI found A09164
# finding words, lemmas, and POS
# text found
# TEI found A09836
# finding words, lemmas, and POS
# text found
# TEI found A09169
# finding words, lemmas, and POS
# text found
# TEI found A09567
# finding words, lemmas, and POS
# text found
# TEI found A09515
# finding words, lemmas, and POS
# text found
# TEI found A09277
# finding words, lemmas, and POS
# text found
# TEI found A09587
# finding words, lemmas, and POS
# text found
# TEI found A09069
# finding words, lemmas, and POS
# text found
# TEI found A09478
# finding words, lemmas, and POS
# text found
# TEI found A09489
# finding words, lemmas, and POS
# text found
# TEI found A09898
# finding words, lemmas, and POS
# text found
# TEI found A09041
# finding words, lemmas, and POS
# text found
# TEI found A09920
# finding words, lemmas, and POS
# text found
# TEI found A09431
# finding words, lemmas, and POS
# text found
# TEI found A09036
# finding words, lemmas, and POS
# text found
# TEI found A09109
# finding words, lemmas, and POS
# text found
# TEI found A09299
# finding words, lemmas, and POS
# text found
# TEI found A09280
# finding words, lemmas, and POS
# text found
# TEI found A09511
# finding words, lemmas, and POS
# data frame has successfully been created
# csv has successfully been generated

# %%
def folder_iterator():
    #folder_path = glob.glob(f"/projects/glimp/eebotcp/texts/{folder_name}")
    print (f"processing folder: {folder_name}")
    #xml_paths = folder_path+"/*.xml"
    xml_files = glob.glob(f"/scratch/alpine/naca4005/texts/A09/*.xml")
    
    print ("word dataframe processing")
    by_word_dataframe_maker(xml_files)
    print ("sentence dataframe processing")
    by_sentence_dataframe_maker(xml_files)

# %%
''' RUNNING THE FUNCTION '''

folder_iterator()
# Out:
# processing folder: -f
# word dataframe processing
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-79944b87f3e6> in <module>
#       1 ''' RUNNING THE FUNCTION '''
#       2
# ----> 3 folder_iterator()
#
# <ipython-input-2-c498eaa79550> in folder_iterator()
#       6
#       7     print ("word dataframe processing")
# ----> 8     by_word_dataframe_maker(xml_files)
#       9     print ("sentence dataframe processing")
#      10     by_sentence_dataframe_maker(xml_files)
#
# <ipython-input-1-18699f3c33c2> in by_word_dataframe_maker(files)
#     178
#     179         words = extract_all_words(root)
# --> 180         modernized = extract_all_modernized_words(root)
#     181         lemmas = extract_all_lemmas(root)
#     182         pos = extract_all_pos(root)
#
# <ipython-input-1-18699f3c33c2> in extract_all_modernized_words(text_root)
#      80
#      81 def extract_all_modernized_words(text_root):
# ---> 82     all_word_tags = text_root.findall(".//tei:w",namespaces=nsmap)
#      83
#      84     regularized_words = [w.get('reg', w.text) for w in all_word_tags]
#
# KeyboardInterrupt:
